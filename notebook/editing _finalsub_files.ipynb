# %%
import pandas as pd 
import dask.dataframe as dd
from dask.distributed import Client, progress
from dask.diagnostics import ProgressBar

# %%
ddf = dd.read_csv("SubCh1/my_result_for_p.HER2_c_SubCh1/*")

# %%
my_df_pred = ddf.compute()

# %%
df = pd.read_csv("models_templates/subchallenge_1_template_data.csv")

# %%
df.columns
# Out:
# Index(['glob_cellID', 'cell_line', 'treatment', 'time', 'cellID', 'fileID',
#        'p.ERK', 'p.Akt.Ser473.', 'p.S6', 'p.HER2', 'p.PLCg2'],
#       dtype='object')

# %%
df.shape,
# Out:
# ((2383058, 11),)

# %%
my_df_pred.shape
# Out:
# (1826812, 2)

# %%
my_df_pred["Unnamed: 0"]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#           ...
# 45321    1826807
# 45322    1826808
# 45323    1826809
# 45324    1826810
# 45325    1826811
# Name: Unnamed: 0, Length: 1826812, dtype: object

# %%
my_df_pred = my_df_pred.rename(columns={"Unnamed: 0": "my_index"})

# %%
my_df_pred.head()
# Out:
#   my_index p.HER2_c
# 0        0  4.47132
# 1        1  4.41582
# 2        2  5.57573
# 3        3  4.24628
# 4        4  4.27372

# %%
# my_df_pred[my_df_pred["my_index"] < df.shape[0] ]

# %%
my_df_pred = pd.read_csv("subchallenge_1_results_data.csv")

# %%
my_test = df["fileID"].unique()

# %%
my_test
# Out:
# array([  59,  122,   69,   35,   68,   36,   70,   38,   71,   75,   72,
#          58,  121,   65,  112,   57,   45,   64,   50,   41,   54,   67,
#         120,   74,   79,   81,   77,   44,   56,   43,   62,   46,   37,
#          34,   48,   39,   51,   66,  119,   73,   78,   80,   76,   42,
#          55, 1145, 1197, 1112, 1154, 1113, 1153, 1114, 1155, 1116, 1156,
#        1127, 1157, 1144, 1196, 1150, 1191, 1143, 1124, 1126, 1135, 1119,
#        1138, 1152, 1193, 1159, 1129, 1140, 1161, 1122, 1142, 1121, 1148,
#        1131, 1115, 1111, 1133, 1117, 1136, 1151, 1192, 1158, 1128, 1130,
#        1160, 1120, 1139, 2230, 2296, 2238, 2284, 2222, 2276, 2237, 2278,
#        2231, 2277, 2228, 2270, 2229, 2295, 2212, 2290, 2285, 2217, 2232,
#        2279, 2223, 2271, 2213, 2291, 2286, 2218, 2233, 2280, 2224, 2272,
#        2215, 2293, 2288, 2220, 2235, 2282, 2226, 2274, 2216, 2294, 2289,
#        2221, 2236, 2283, 2227, 2275, 1600, 1662, 1602, 1671, 1603, 1670,
#        1604, 1672, 1606, 1673, 1616, 1674, 1599, 1661, 1594, 1667, 1660,
#        1613, 1615, 1654, 1609, 1657, 1596, 1669, 1676, 1618, 1620, 1678,
#        1611, 1659, 1592, 1665, 1650, 1605, 1601, 1652, 1607, 1655, 1595,
#        1668, 1675, 1617, 1619, 1677, 1610, 1658, 1280, 1313, 1282, 1322,
#        1283, 1321, 1284, 1323, 1286, 1324, 1296, 1325, 1279, 1312, 1274,
#        1318, 1311, 1293, 1295, 1305, 1289, 1308, 1276, 1320, 1327, 1298,
#        1300, 1329, 1291, 1310, 1272, 1316, 1301, 1285, 1281, 1303, 1287,
#        1306, 1275, 1319, 1326, 1297, 1299, 1328, 1290, 1309,  401,  433,
#         403,  442,  404,  441,  405,  443,  407,  444,  417,  445,  400,
#         432,  438,  431,  414,  416,  425,  410,  428,  440,  447,  418,
#         420,  449,  412,  430,  436,  421,  406,  402,  423,  408,  426,
#         398,  439,  446,  419,  448,  411,  429, 2098, 2126, 2100, 2135,
#        2101, 2134, 2102, 2136, 2104, 2137, 2114, 2138, 2097, 2125, 2092,
#        2131, 2124, 2111, 2113, 2123, 2107, 2094, 2133, 2140, 2116, 2118,
#        2142, 2109, 2090, 2129, 2119, 2103, 2099, 2121, 2105, 2093, 2132,
#        2139, 2115, 2117, 2141, 2108])

# %%
# for x in my_df_pred["fileID"].unique():
#     if x in my_test: 
#         print (x)

# %%
my_df_pred[~my_df_pred["fileID"].isin(my_test)]
# Out:
#          Unnamed: 0 cell_line  time  cellID  fileID  b.CATENIN  cleavedCas  \
# 0                 0     AU565   0.0     1.0    89.5   0.908752    2.648422
# 1                 1     AU565   0.0     2.0    89.5   0.907266    2.935780
# 2                 2     AU565   0.0     3.0    89.5   1.372125    3.562005
# 3                 3     AU565   0.0     4.0    89.5   0.719505    2.176994
# 4                 4     AU565   0.0     5.0    89.5   1.297900    1.388315
# ...             ...       ...   ...     ...     ...        ...         ...
# 1788085        6599    MACLS2   0.0  5706.0  1296.5   1.032309    2.028467
# 1788095        6609    MACLS2   0.0  5707.0  1296.5   0.638170    3.786171
# 1788105        6619    MACLS2   0.0  5708.0  1296.5   0.833834    2.825543
# 1788115        6629    MACLS2   0.0  5709.0  1296.5   1.028399    3.031983
# 1788125        6639    MACLS2   0.0  5710.0  1296.5   0.510859    1.486199
#
#           CyclinB     GAPDH       IdU  ...     p.SRC   p.STAT1   p.STAT3  \
# 0        2.032845  2.217437  5.436810  ...  2.463506  2.945925  2.212194
# 1        1.204890  2.130749  9.761665  ...  2.750738  3.072018  1.335012
# 2        5.088355  3.469405  9.223250  ...  3.001770  3.877995  2.363232
# 3        1.556060  2.556309  5.603660  ...  1.749490  2.001521  1.975592
# 4        2.224105  2.502649  5.605645  ...  1.706431  2.752900  0.652426
# ...           ...       ...       ...  ...       ...       ...       ...
# 1788085  2.803060  2.348707  9.580535  ...  2.807585  3.478555  2.113655
# 1788095  2.378910  3.462000  6.571135  ...  2.899097  3.696095  2.188410
# 1788105  2.630795  1.684453  6.522045  ...  1.484628  3.638220  0.652426
# 1788115  2.065000  1.950151  8.565095  ...  2.038762  3.288515  2.800079
# 1788125  1.647485  1.296674  6.839650  ...  0.871314  1.993285  1.137804
#
#           p.STAT5  treatment     p.ERK  p.Akt.Ser473.      p.S6    p.HER2  \
# 0        2.292276       full  2.834188       3.426448  5.756456  4.471318
# 1        2.203515       full  3.538905       3.647334  5.907770  4.415816
# 2        3.062663       full  4.735539       4.757451  7.993566  5.575728
# 3        2.157024       full  3.034737       3.263650  5.256627  4.246282
# 4        2.051459       full  3.251555       3.298982  5.299768  4.273718
# ...           ...        ...       ...            ...       ...       ...
# 1788085  2.483393        EGF  3.257962       3.341822  6.335834  4.446434
# 1788095  2.862956        EGF  3.766235       4.113511  6.633518  4.715013
# 1788105  2.106464        EGF  2.914401       2.843948  4.908262  4.267304
# 1788115  2.369001        EGF  3.144902       3.042400  5.411113  4.408137
# 1788125  2.104860        EGF  1.887393       2.658569  3.921870  3.588282
#
#           p.PLCg2
# 0        2.251685
# 1        2.556171
# 2        3.458247
# 3        1.937342
# 4        2.017390
# ...           ...
# 1788085  2.616131
# 1788095  3.142022
# 1788105  1.692604
# 1788115  2.403643
# 1788125  1.518878
#
# [342545 rows x 43 columns]

# %%
# for x in my_df_pred["fileID"].unique():
#     print (round(x))
    
my_test = [round(x) for x in my_df_pred["fileID"].unique() ]

# %%
my_df_pred["fileID_2"]= my_df_pred["fileID"].apply(round)

# %%
my_df_pred.columns
# Out:
# Index(['Unnamed: 0', 'cell_line', 'time', 'cellID', 'fileID', 'b.CATENIN',
#        'cleavedCas', 'CyclinB', 'GAPDH', 'IdU', 'Ki.67', 'p.4EBP1',
#        'p.AKT.Thr308.', 'p.AMPK', 'p.BTK', 'p.CREB', 'p.FAK', 'p.GSK3b',
#        'p.H3', 'p.JNK', 'p.MAP2K3', 'p.MAPKAPK2', 'p.MEK', 'p.MKK3.MKK6',
#        'p.MKK4', 'p.NFkB', 'p.p38', 'p.p53', 'p.p90RSK', 'p.PDPK1', 'p.RB',
#        'p.S6K', 'p.SMAD23', 'p.SRC', 'p.STAT1', 'p.STAT3', 'p.STAT5',
#        'treatment', 'p.ERK', 'p.Akt.Ser473.', 'p.S6', 'p.HER2', 'p.PLCg2',
#        'fileID_2'],
#       dtype='object')

# %%
out_siders = my_df_pred[~my_df_pred["fileID_2"].isin(my_test)]

# %%
2383058 - 1461003
# Out:
# 922055

# %%
out_siders.shape
# Out:
# (365809, 44)

# %%
test= out_siders[['cell_line', 'treatment', 'time', 'cellID', 'fileID','p.ERK',
             'p.Akt.Ser473.', 'p.S6', 'p.HER2', 'p.PLCg2']]

# %%
my_list = []
counter = df.shape[0]
with ProgressBar() : 
    for x in df.itertuples():
        counter = counter -1
        print (counter ,end = ' ')
    #     for y in test[:10].itertuples():
    #         if x[3] ==  y[1] and x[4] ==y[2] and x[3] == y[2] and x[4] ==y[4]:
    #     print (x[2],x[3],x[4],x[5])
        for y in test.itertuples():
    #         print (y[1],y[2],y[3],y[4])
            if x[2]==y[1] and x[3]==y[2] and x[4]==y[3] and x[5]==y[4]:
    #              print (y[1],y[2],y[3],y[4],x[6],y[6],y[7],y[8],y[9],y[10])
                 my_list.append((y[1],y[2],y[3],y[4],x[6],y[6],y[7],y[8],y[9],y[10]))
    #             print (y[1:5],x[6],y[6:])
# Out:
# 2383057 2383056 2383055 2383054 2383053 2383052 2383051 2383050 2383049 2383048 2383047 2383046 2383045 2383044 2383043 2383042 2383041 2383040 2383039 2383038 2383037 2383036 2383035 2383034 2383033 2383032 2383031 2383030 2383029 2383028 2383027 2383026 2383025 2383024 2383023 2383022 2383021 2383020 2383019 2383018 2383017 2383016 2383015 2383014 2383013 2383012 2383011 2383010 2383009 2383008 2383007 2383006 2383005 2383004 2383003 2383002 2383001 2383000 2382999 2382998 2382997 2382996 2382995 2382994 2382993 2382992 2382991 2382990 2382989 2382988 2382987 2382986 2382985 2382984 2382983 2382982 2382981 2382980 2382979 2382978 2382977 2382976 2382975 2382974 2382973 2382972 2382971 2382970 2382969 2382968 2382967 2382966 2382965 2382964 2382963 2382962 2382961 2382960 2382959 2382958 2382957 2382956 2382955 2382954 2382953 2382952 2382951 2382950 2382949 2382948 2382947 2382946 2382945 2382944 2382943 2382942 2382941 2382940 2382939 2382938 2382937 2382936 2382935 2382934 2382933 2382932 2382931 2382930 2382929 2382928 2382927 2382926 2382925 2382924 2382923 2382922 2382921 2382920 2382919 2382918 2382917 2382916 2382915 2382914 2382913 2382912 2382911 2382910 2382909 2382908 2382907 2382906 2382905 2382904 2382903 2382902 2382901 2382900 2382899 2382898 2382897 2382896 2382895 2382894 2382893 2382892 2382891 2382890 2382889 2382888 2382887 2382886 2382885 2382884 2382883 2382882 2382881 2382880 2382879 2382878 2382877 2382876 2382875 2382874 2382873 2382872 2382871 2382870 2382869 2382868 2382867 2382866 2382865 2382864 2382863 2382862 2382861 2382860 2382859 2382858 2382857 2382856 2382855 2382854 2382853 2382852 2382851 2382850 2382849 2382848 2382847 2382846 2382845 2382844 2382843 2382842 2382841 2382840 2382839 2382838 2382837 2382836 2382835 2382834 2382833 2382832 2382831 2382830 2382829 2382828 2382827 2382826 2382825 2382824 2382823 2382822 2382821 2382820 2382819 2382818 2382817 2382816 2382815 2382814 2382813 2382812 2382811 2382810 2382809 2382808 2382807 2382806 2382805 2382804 2382803 2382802 2382801 2382800 2382799 2382798 2382797 2382796 2382795 2382794 2382793 2382792 2382791 2382790 2382789 2382788 2382787 2382786 2382785 2382784 2382783 2382782 2382781 2382780 2382779 2382778 2382777 2382776 2382775 2382774 2382773 2382772 2382771 2382770 2382769 2382768 2382767 2382766 2382765 2382764 2382763 2382762 2382761 2382760 2382759 2382758 2382757 2382756 2382755 2382754 2382753 2382752 2382751 2382750 2382749 2382748 2382747 2382746 2382745 2382744 2382743 2382742 2382741 2382740 2382739 2382738 2382737 2382736 2382735 2382734 2382733 2382732 2382731 2382730 2382729 2382728 2382727 2382726 2382725 2382724 2382723 2382722 2382721 2382720 2382719 2382718 2382717 2382716 2382715 2382714 2382713 2382712 2382711 2382710 2382709 2382708 2382707 2382706 2382705 2382704 2382703 2382702 2382701 2382700 2382699 2382698 2382697 2382696 2382695 2382694 2382693 2382692 2382691 2382690 2382689 2382688 2382687 2382686 2382685 2382684 2382683 2382682 2382681 2382680 2382679 2382678 2382677 2382676 2382675 2382674 2382673 2382672 2382671 2382670 2382669 2382668 2382667 2382666 2382665 2382664 2382663 2382662 2382661 2382660 2382659 2382658 2382657 2382656 2382655 2382654 2382653 2382652 2382651 2382650 2382649 2382648 2382647 2382646 2382645 2382644 2382643 2382642 2382641 2382640 2382639 2382638 2382637 2382636 2382635 2382634 2382633 2382632 2382631 2382630 2382629 2382628 2382627 2382626 2382625 2382624 2382623 2382622 2382621 2382620 2382619 2382618 2382617 2382616 2382615 2382614 2382613 2382612 2382611 2382610 2382609 2382608 2382607 2382606 2382605 2382604 2382603 2382602
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-f8393638c1a1> in <module>
#       8     #         if x[3] ==  y[1] and x[4] ==y[2] and x[3] == y[2] and x[4] ==y[4]:
#       9     #     print (x[2],x[3],x[4],x[5])
# ---> 10         for y in test.itertuples():
#      11     #         print (y[1],y[2],y[3],y[4])
#      12             if x[2]==y[1] and x[3]==y[2] and x[4]==y[3] and x[5]==y[4]:
#
# <string> in _make(cls, iterable, new, len)
#
# KeyboardInterrupt:

# %%
# df = df[['cell_line', 'treatment', 'time', 'cellID', 'fileID','p.ERK',
#              'p.Akt.Ser473.', 'p.S6', 'p.HER2', 'p.PLCg2']]

# %%
df_outer = pd.merge(df, my_df_pred, on=['cell_line', 'treatment', 'time', 'cellID'], how='outer')

# %%
df_outer.columns
# Out:
# Index(['glob_cellID', 'cell_line', 'treatment', 'time', 'cellID', 'fileID_x',
#        'p.ERK_x', 'p.Akt.Ser473._x', 'p.S6_x', 'p.HER2_x', 'p.PLCg2_x',
#        'Unnamed: 0', 'fileID_y', 'b.CATENIN', 'cleavedCas', 'CyclinB', 'GAPDH',
#        'IdU', 'Ki.67', 'p.4EBP1', 'p.AKT.Thr308.', 'p.AMPK', 'p.BTK', 'p.CREB',
#        'p.FAK', 'p.GSK3b', 'p.H3', 'p.JNK', 'p.MAP2K3', 'p.MAPKAPK2', 'p.MEK',
#        'p.MKK3.MKK6', 'p.MKK4', 'p.NFkB', 'p.p38', 'p.p53', 'p.p90RSK',
#        'p.PDPK1', 'p.RB', 'p.S6K', 'p.SMAD23', 'p.SRC', 'p.STAT1', 'p.STAT3',
#        'p.STAT5', 'p.ERK_y', 'p.Akt.Ser473._y', 'p.S6_y', 'p.HER2_y',
#        'p.PLCg2_y', 'fileID_2'],
#       dtype='object')

# %%
df_outer= df_outer[[ 'glob_cellID', 'cell_line', 'treatment', 'time', 
          'cellID', 'fileID_x','p.ERK_y', 'p.Akt.Ser473._y', 'p.S6_y', 'p.HER2_y', 'p.PLCg2_y' ]]

# %%
df_outer.columns = ['glob_cellID','cell_line', 'treatment', 'time', 'cellID', 'fileID','p.ERK',
             'p.Akt.Ser473.', 'p.S6', 'p.HER2', 'p.PLCg2']

# %%
df_outer.head()
# Out:
#    glob_cellID cell_line treatment  time  cellID  fileID     p.ERK  \
# 0            1     AU565       EGF   0.0       1      59  4.034421
# 1            2     AU565       EGF   0.0       1     122  4.034421
# 2            3     AU565       EGF   0.0       2      59  3.731097
# 3            4     AU565       EGF   0.0       2     122  3.731097
# 4            5     AU565       EGF   0.0       3      59  3.320674
#
#    p.Akt.Ser473.      p.S6    p.HER2   p.PLCg2
# 0       4.032121  5.915276  4.599742  2.792010
# 1       4.032121  5.915276  4.599742  2.792010
# 2       3.728756  5.843169  4.495839  2.332266
# 3       3.728756  5.843169  4.495839  2.332266
# 4       3.411983  4.887949  4.383874  2.214855

# %%
df.shape, df_outer.shape
# Out:
# ((2383058, 10), (2388996, 10))

# %%
2383058 - 2388996
# Out:
# -5938

# %%
for x in df_outer.columns:
    print (df_outer[df_outer["p.ERK"].isna()].shape)
# Out:
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)
# (0, 10)

# %%
df_outer.to_csv("subchallenge_1_template_data_DBB.csv",index=False)

# %%
to_fill = pd.read_csv("models_templates/subchallenge_2_template_data.csv")

# %%
to_fill.cell_line.unique()
# Out:
# array(['184B5', 'BT483', 'HCC1428', 'HCC1806', 'HCC202', 'Hs578T',
#        'MCF12A', 'MDAMB231', 'MDAMB468', 'SKBR3', 'UACC3199', 'ZR751'],
#       dtype=object)

# %%
to_fill.columns
# Out:
# Index(['cell_line', 'treatment', 'time', 'cellID', 'b.CATENIN', 'cleavedCas',
#        'CyclinB', 'GAPDH', 'IdU', 'Ki.67', 'p.4EBP1', 'p.Akt.Ser473.',
#        'p.AKT.Thr308.', 'p.AMPK', 'p.BTK', 'p.CREB', 'p.ERK', 'p.FAK',
#        'p.GSK3b', 'p.H3', 'p.JNK', 'p.MAP2K3', 'p.MAPKAPK2', 'p.MEK',
#        'p.MKK3.MKK6', 'p.MKK4', 'p.NFkB', 'p.p38', 'p.p53', 'p.p90RSK',
#        'p.PDPK1', 'p.RB', 'p.S6', 'p.S6K', 'p.SMAD23', 'p.SRC', 'p.STAT1',
#        'p.STAT3', 'p.STAT5'],
#       dtype='object')

# %%
df_outer.columns
# Out:
# Index(['cell_line', 'treatment', 'time', 'cellID', 'fileID', 'p.ERK',
#        'p.Akt.Ser473.', 'p.S6', 'p.HER2', 'p.PLCg2'],
#       dtype='object')

# %%
glob_cellID, cell_line, treatment, time, cellID, fileID, p.Akt.Ser473., p.ERK, p.HER2, p.PLCg2, p.S6
